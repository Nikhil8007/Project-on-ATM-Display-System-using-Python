# %% [markdown]
# # ATM PROJECT

# %%
import random
import sys
from getpass import getpass

class ATM():
    def __init__(self, name, account_number, balance, pin, Mobile):
        self.name=name
        self.account_number=account_number
        self.balance=balance
        self.pin=pin
        self.Mobile=Mobile
        
    def account_detail(self):
        chance=3
        while chance != 0:
            P=int(getpass("Enter Your Pin"))
            print("===================================")
            if P == pin:
                print("\n----------ACCOUNT DETAIL----------")
                print(f"Account Holder: {self.name.upper()}")
                print(f"Account Number: {self.account_number}")    
                print(f"Avilable Balance: {self.balance}")
                print(f"Phone number : {self.Mobile}")
                print("````````````````````````````````````")
                per=input("Enter y for back to main manu : ")
                print("````````````````````````````````````")
                if per == "y":
                    break    
            else:
                chance-=1
                print("````````````````````````````````````")
                print("Your pin is not correct")
                print(f"you have {chance} number od chances left.")
                print("````````````````````````````````````")
                if chance==0:
                    print("your pin is locked")
                    print("````````````````````````````````````")
            continue          
            
    def deposit(self,amount):
        chance=3
        while chance != 0:
            P=int(getpass("Enter Your Pin"))
            print("===================================")
            if P == pin:
                self.amount=amount
                self.balance=self.balance+self.amount
                print("Current account balance is : ",self.balance)
                print("````````````````````````````````````")
                per=input("Enter y for back to main manu : ")
                print("````````````````````````````````````")
                if per == "y":
                    break
                else:
                    print("Enter proper key")
            else:
                chance-=1
                print("````````````````````````````````````")
                print("Your pin is not correct")
                print(f"you have {chance} number od chances left.")
                print("````````````````````````````````````")
                if chance==0:
                    print("your pin is locked")
                    print("````````````````````````````````````")
            continue
              
    def withdraw(self,amount):
        chance=3
        while chance != 0:
            P=int(getpass("Enter Your Pin"))
            print("===================================")
            if P == pin:
                self.amount=amount
                if self.amount>self.balance:
                    print(f"your balance is {self.balance} only")
                    print("````````````````````````````````````")
                    per=input("Enter y for back to main manu : ")
                    print("````````````````````````````````````")
                    if per == "y":
                        break
                elif self.amount<self.balance:
                    self.balance=self.balance - self.amount
                    print(f"{self.amount} is withdrawal successful. \nCurrent account balance is :",self.balance)
                    print("````````````````````````````````````")
                    per=input("Enter y for back to main manu : ")
                    print("````````````````````````````````````")
                    if per == "y":
                        break
            else:
                chance-=1
                print("````````````````````````````````````")
                print("Your pin is not correct")
                print(f"you have {chance} number od chances left.")
                print("````````````````````````````````````")
                if chance==0:
                    print("your pin is locked")
                    print("````````````````````````````````````")
            continue
            
            
    def check_balance(self):
        chance=3
        while chance != 0:
            P=int(getpass("Enter Your Pin"))
            print("===================================")
            if P == pin:
                print("Available balance is : ",self.balance)
                print("````````````````````````````````````")
                per=input("Enter y for back to main manu : ")
                print("````````````````````````````````````")
                if per == "y":
                    break
            else:
                chance-=1
                print("````````````````````````````````````")
                print("Your pin is not correct")
                print(f"you have {chance} number od chances left.")
                print("````````````````````````````````````")
                if chance==0:
                    print("your pin is locked")
                    print("````````````````````````````````````")
            continue    
        
    def transaction(self):
        while True:
            print("   TRANSACTION    \n*************** \nMenu: \nSelect Transaction \n1.Account Detail      2.Check Balance \n3.Deposit             4.Withdraw \n5.Exit            \n***************")
            option=int(input("Enter the value 1 to 5 : "))
            if option==1:
                atm.account_detail()
            elif option==2:
                atm.check_balance()
            elif option==3:
                amount=int(input("Enter the amount how much you want to deposit : "))
                atm.deposit(amount)
            elif option==4:
                amount=int(input("Enter the amount how much you want to Withdraw : "))
                atm.withdraw(amount)
            elif option==5:
                print(f"""
                Printout the receipt
          ==================================
          Transaction is complete.
          Transaction number is : {random.randint(100,10000)}
          Account Holder Name is : {self.name.upper()}
          Account Number is : {self.account_number}
          Available balance is : {self.balance}
          Phone number is : {self.Mobile}
       
       **********Thank You***********
       """)
                break
            else:
                print("Enter the valid number between 1 to 5, Only!")
                
            

            
print("~~~~~~~WELCOME TO BANK OF EDU~~~~~~~~")
print("*********ACCOUNT CREATION************")
name = input("Enter the name of account holder : ")
pin=int(getpass("Enter yor generate_pin : "))
account_number = int(input("Enter your account number: "))
balance = 0
Mobile = int(input("Enter your Phone number : "))
print("Congratulations! Account created successfully and generate_pin")
          
atm= ATM(name, account_number, balance, pin, Mobile)          
          
while True:
        print("`````````````````````````````````````````````")
        Transaction=input("Do you want to do transaction?select(y or n) : ")
        print("`````````````````````````````````````````````")
        if Transaction == "y" :
            atm.transaction()
            
        elif Transaction == "n" :
            print("""     
            ------------------------------------------------
            Thanks for choosing us your bank visit us again!
            ------------------------------------------------
            """)
            break
        
        else:
            print("Wrong command! Enter only 'y' either 'n'.")
# Out:
# ~~~~~~~WELCOME TO BANK OF EDU~~~~~~~~
# *********ACCOUNT CREATION************
# Enter the name of account holder : naveen
# Enter yor generate_pin : ········
# Enter your account number: 36545663
# Enter your Phone number : 8221820724
# Congratulations! Account created successfully and generate_pin
# `````````````````````````````````````````````
# Do you want to do transaction?select(y or n) : y
# `````````````````````````````````````````````
#    TRANSACTION
# ***************
# Menu:
# Select Transaction
# 1.Account Detail      2.Check Balance
# 3.Deposit             4.Withdraw
# 5.Exit
# ***************
# Enter the value 1 to 5 : 1
# Enter Your Pin········
# ...
# ````````````````````````````````````
# Your pin is not correct
# you have 2 number od chances left.
# ````````````````````````````````````
# Enter Your Pin········
# ...
# ````````````````````````````````````
# Your pin is not correct
# you have 1 number od chances left.
# ````````````````````````````````````
# ...
